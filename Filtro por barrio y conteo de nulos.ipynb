# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from datetime import datetime
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('properatti.csv',encoding='' )

# %%
pf = pd.DataFrame(data)

# %%
#Reducir el data set a cap fed
mask_capitalFederal = pf['state_name'] == 'Capital Federal'

dataset = pf[mask_capitalFederal]

dataset
# Out:
#         Unnamed: 0 operation property_type       place_name  \
# 0                0      sell            PH        Mataderos
# 2                2      sell     apartment        Mataderos
# 3                3      sell            PH          Liniers
# 7                7      sell     apartment         Belgrano
# 8                8      sell     apartment         Belgrano
# ...            ...       ...           ...              ...
# 121160      121160      sell     apartment         Belgrano
# 121209      121209      sell     apartment         Belgrano
# 121215      121215      sell     apartment         Belgrano
# 121217      121217      sell     apartment    Villa Urquiza
# 121219      121219      sell     apartment  Capital Federal
#
#                           place_with_parent_names country_name  \
# 0           |Argentina|Capital Federal|Mataderos|    Argentina
# 2           |Argentina|Capital Federal|Mataderos|    Argentina
# ...

# %%
dataset_2 = dataset.loc[:,['place_name', 'lat-lon']]

# %%
dataset_2
# Out:
#              place_name                        lat-lon
# 0             Mataderos        -34.6618237,-58.5088387
# 2             Mataderos        -34.6522615,-58.5229825
# 3               Liniers        -34.6477969,-58.5164244
# 7              Belgrano         -34.5598729,-58.443362
# 8              Belgrano         -34.5598729,-58.443362
# ...                 ...                            ...
# 121160         Belgrano   -34.563685346,-58.4426825896
# 121209         Belgrano   -34.563685346,-58.4426825896
# 121215         Belgrano                            NaN
# 121217    Villa Urquiza  -34.5706388726,-58.4755963355
# 121219  Capital Federal                            NaN
#
# [32316 rows x 2 columns]

# %%
#Data series de los barrios
series_place_name =  dataset['place_name']

# %%
series_place_name
# Out:
# 0               Mataderos
# 2               Mataderos
# 3                 Liniers
# 7                Belgrano
# 8                Belgrano
#                ...
# 121160           Belgrano
# 121209           Belgrano
# 121215           Belgrano
# 121217      Villa Urquiza
# 121219    Capital Federal
# Name: place_name, Length: 32316, dtype: object

# %%
#Ver si hay algun nulo en la columna de los barrios (de cap fed)
series_place_null = series_place_name.isnull()

# %%
info_series_place_null = series_place_null.sum()

# %%
info_series_place_null
# Out:
# 0

# %%
series_place_name.value_counts()
# Out:
# Belgrano           2992
# Palermo            2885
# Caballito          2273
# Villa Urquiza      1629
# Recoleta           1547
#                    ...
# Velez Sarsfield      39
# Villa Real           37
# Villa Soldati        15
# Villa Riachuelo       6
# Catalinas             4
# Name: place_name, Length: 62, dtype: int64

# %%
series_place_name.value_counts().sum()
# Out:
# 32316

# %%
info_por_barrio = series_place_name.value_counts()

# %%
info_por_barrio
# Out:
# Belgrano           2992
# Palermo            2885
# Caballito          2273
# Villa Urquiza      1629
# Recoleta           1547
#                    ...
# Velez Sarsfield      39
# Villa Real           37
# Villa Soldati        15
# Villa Riachuelo       6
# Catalinas             4
# Name: place_name, Length: 62, dtype: int64

# %%
lat_lon = dataset['lat-lon']

# %%
lat_lon
# Out:
# 0               -34.6618237,-58.5088387
# 2               -34.6522615,-58.5229825
# 3               -34.6477969,-58.5164244
# 7                -34.5598729,-58.443362
# 8                -34.5598729,-58.443362
#                       ...
# 121160     -34.563685346,-58.4426825896
# 121209     -34.563685346,-58.4426825896
# 121215                              NaN
# 121217    -34.5706388726,-58.4755963355
# 121219                              NaN
# Name: lat-lon, Length: 32316, dtype: object

# %%
lat_lon_null = lat_lon.isnull()

# %%
info_lat_lon_null = lat_lon_null.sum()

# %%
info_lat_lon_null
# Out:
# 8546
