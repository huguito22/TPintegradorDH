# %%
import pandas as pd
import numpy as np
import re
data = pd.read_csv('properatti.csv')

# %%
title = data['title']
title
# Out:
# 0                        2 AMB TIPO CASA SIN EXPENSAS EN PB
# 1         VENTA Depto 2 dorm. a estrenar 7 e/ 36 y 37   ...
# 2                  2 AMB 3ER PISO CON ASCENSOR APTO CREDITO
# 3                              PH 3 amb. cfte. reciclado
# 4         DEPTO 2 AMB AL CONTRAFRENTE ZONA CENTRO/PLAZA ...
#                                 ...
# 121215           Torre Forum Alcorta- Impecable 3 ambientes
# 121216    Ruca Inmuebles | Venta | Lomas de San Isidro |...
# 121217    VENTA DEPARTAMENTO AMBIENTE DIVISIBLE A ESTREN...
# 121218    2 amb. C/ dep. de servicio al contrafrente| Re...
# 121219           Departamento apto profesional en el Centro
# Name: title, Length: 121220, dtype: object

# %%
#buscamos mediante un patron y el uso de expresiones regulares los precios en USD que estan en la columna de title
patron = '^U\$D \d*.\d* '
title_regex = re.compile(patron)
resultado = title.apply(lambda x:  x if x is np.NaN else title_regex.search(x))
resultado
# Out:
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
#           ...
# 121215    None
# 121216    None
# 121217    None
# 121218    None
# 121219    None
# Name: title, Length: 121220, dtype: object

# %%
# las coincidencias con el patron se volcaron a nueva columna Titleclean
mask_notnull = resultado.notnull()
data.loc[mask_notnull, "TitleClean"] = resultado[mask_notnull].apply(lambda x: x.group(0))
dolar= data.loc[mask_notnull, ["TitleClean"]]
dolar
# Out:
#          TitleClean
# 1665   U$D 260.000
# 1666   U$D 115.000
# 1667   U$D 740.000
# 1668   U$D 740.000
# 1669   U$D 740.000
# ...             ...
# 4276    U$D 72.000
# 4278   U$D 115.000
# 4279    U$D 74.000
# 4280    U$D 85.000
# 50371  U$D 180.000
#
# [2409 rows x 1 columns]

# %%
title_clean = data['TitleClean']
title_clean2 = title_clean.apply(str)
type(title_clean2)
title_clean2
# Out:
# 0         nan
# 1         nan
# 2         nan
# 3         nan
# 4         nan
#          ...
# 121215    nan
# 121216    nan
# 121217    nan
# 121218    nan
# 121219    nan
# Name: TitleClean, Length: 121220, dtype: object

# %%
# mediante el uso de un nuevo patron quitamos el signo U$D para quedarnos solo con el precio (sin la moneda)
patron_usd = '\d+.\d+'
title_clean2_regex = re.compile(patron_usd)
resultado2 = title_clean2.apply(lambda x:  x if x is np.NaN else title_clean2_regex.search(x))
resultado2
# Out:
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
#           ...
# 121215    None
# 121216    None
# 121217    None
# 121218    None
# 121219    None
# Name: TitleClean, Length: 121220, dtype: object

# %%
# lo volcamos a una nueva columna SinUSD
mask2_notnull = resultado2.notnull()
data.loc[mask2_notnull, "SinUSD"] = resultado2[mask2_notnull].apply(lambda x: x.group(0))
dolar2= data.loc[mask2_notnull, ["SinUSD"]]
dolar2
# Out:
#         SinUSD
# 1665   260.000
# 1666   115.000
# 1667   740.000
# 1668   740.000
# 1669   740.000
# ...        ...
# 4276    72.000
# 4278   115.000
# 4279    74.000
# 4280    85.000
# 50371  180.000
#
# [2387 rows x 1 columns]

# %%
#completamos los campos vacios de precios en usd por lo nuevos ,sacados de title, reflejados en SinUSD
data.price_aprox_usd.fillna(data.SinUSD, inplace=True)

# %%
#creamos un sub data solo con los valores de Capital Federal
caba = data.state_name == "Capital Federal"
data_caba = data [caba]
data_caba
# Out:
#         Unnamed: 0 operation property_type       place_name  \
# 0                0      sell            PH        Mataderos
# 2                2      sell     apartment        Mataderos
# 3                3      sell            PH          Liniers
# 7                7      sell     apartment         Belgrano
# 8                8      sell     apartment         Belgrano
# ...            ...       ...           ...              ...
# 121160      121160      sell     apartment         Belgrano
# 121209      121209      sell     apartment         Belgrano
# 121215      121215      sell     apartment         Belgrano
# 121217      121217      sell     apartment    Villa Urquiza
# 121219      121219      sell     apartment  Capital Federal
#
#                           place_with_parent_names country_name  \
# 0           |Argentina|Capital Federal|Mataderos|    Argentina
# 2           |Argentina|Capital Federal|Mataderos|    Argentina
# 3             |Argentina|Capital Federal|Liniers|    Argentina
# 7            |Argentina|Capital Federal|Belgrano|    Argentina
# 8            |Argentina|Capital Federal|Belgrano|    Argentina
# ...                                           ...          ...
# 121160       |Argentina|Capital Federal|Belgrano|    Argentina
# 121209       |Argentina|Capital Federal|Belgrano|    Argentina
# 121215       |Argentina|Capital Federal|Belgrano|    Argentina
# 121217  |Argentina|Capital Federal|Villa Urquiza|    Argentina
# 121219                |Argentina|Capital Federal|    Argentina
#
#              state_name  geonames_id                        lat-lon  \
# 0       Capital Federal    3430787.0        -34.6618237,-58.5088387
# 2       Capital Federal    3430787.0        -34.6522615,-58.5229825
# 3       Capital Federal    3431333.0        -34.6477969,-58.5164244
# 7       Capital Federal    3436077.0         -34.5598729,-58.443362
# 8       Capital Federal    3436077.0         -34.5598729,-58.443362
# ...                 ...          ...                            ...
# 121160  Capital Federal    3436077.0   -34.563685346,-58.4426825896
# 121209  Capital Federal    3436077.0   -34.563685346,-58.4426825896
# 121215  Capital Federal    3436077.0                            NaN
# 121217  Capital Federal    3433775.0  -34.5706388726,-58.4755963355
# 121219  Capital Federal    3433955.0                            NaN
#
#               lat  ...  price_per_m2  floor rooms  expenses  \
# 0      -34.661824  ...   1550.000000    NaN   NaN       NaN
# 2      -34.652262  ...   1309.090909    NaN   NaN       NaN
# 3      -34.647797  ...           NaN    NaN   NaN       NaN
# 7      -34.559873  ...   3450.000000    NaN   NaN       NaN
# 8      -34.559873  ...   3250.000000    NaN   NaN       NaN
# ...           ...  ...           ...    ...   ...       ...
# 121160 -34.563685  ...           NaN    NaN   NaN    6300.0
# 121209 -34.563685  ...           NaN    NaN   NaN    6300.0
# 121215        NaN  ...   9354.838710    NaN   NaN   10000.0
# 121217 -34.570639  ...   3371.794872    NaN   NaN       NaN
# 121219        NaN  ...   1675.324675    NaN   NaN    3500.0
#
#                                             properati_url  \
# 0       http://www.properati.com.ar/15bo8_venta_ph_mat...
# 2       http://www.properati.com.ar/15bod_venta_depart...
# 3       http://www.properati.com.ar/15boh_venta_ph_lin...
# 7       http://www.properati.com.ar/15bot_venta_depart...
# 8       http://www.properati.com.ar/15bou_venta_depart...
# ...                                                   ...
# 121160  http://www.properati.com.ar/1cj5v_venta_depart...
# 121209  http://www.properati.com.ar/1cj7c_venta_depart...
# 121215  http://www.properati.com.ar/1cja2_venta_depart...
# 121217  http://www.properati.com.ar/1cja7_venta_depart...
# 121219  http://www.properati.com.ar/1cjaa_venta_depart...
#
#                                               description  \
# 0       2 AMBIENTES TIPO CASA PLANTA BAJA POR PASILLO,...
# 2       2 AMBIENTES 3ER PISO LATERAL LIVING COMEDOR AM...
# 3       PH 3 ambientes con patio. Hay 3 deptos en lote...
# 7       EXCELENTE MONOAMBIENTE A ESTRENAR AMPLIO SUPER...
# 8       EXCELENTE DOS AMBIENTES  ESTRENAR AMPLIO SUPER...
# ...                                                   ...
# 121160  Edificio en esquina de muy buena categoría de ...
# 121209  Edificio en esquina de muy buena categoría de ...
# 121215  TORRE FORUM ALCORTA - MÁXIMA CATEGORÍA.Impecab...
# 121217  VENTA DEPARTAMENTO AMBIENTE DIVISIBLE A ESTREN...
# 121219  Departamento de 77 m2 apto profesional. Edific...
#
#                                                     title  \
# 0                      2 AMB TIPO CASA SIN EXPENSAS EN PB
# 2                2 AMB 3ER PISO CON ASCENSOR APTO CREDITO
# 3                            PH 3 amb. cfte. reciclado
# 7       JOSE HERNANDEZ 1400 MONOAMBIENTE  ESTRENAR CAT...
# 8       JOSE HERNANDEZ   1400 DOS AMBIENTES ESTRENAR ,...
# ...                                                   ...
# 121160  Av .Luis Maria Campos 1400- Belgrano-Capital F...
# 121209  Av .Luis Maria Campos 1400- Belgrano-Capital F...
# 121215         Torre Forum Alcorta- Impecable 3 ambientes
# 121217  VENTA DEPARTAMENTO AMBIENTE DIVISIBLE A ESTREN...
# 121219         Departamento apto profesional en el Centro
#
#                                           image_thumbnail  TitleClean  SinUSD
# 0       https://thumbs4.properati.com/8/BluUYiHJLhgIIK...         NaN     NaN
# 2       https://thumbs4.properati.com/5/SXKr34F_IwG3W_...         NaN     NaN
# 3       https://thumbs4.properati.com/3/DgIfX-85Mog5SP...         NaN     NaN
# 7       https://thumbs4.properati.com/1/IHxARynlr8sPEW...         NaN     NaN
# 8       https://thumbs4.properati.com/2/J3zOjgaFHrkvnv...         NaN     NaN
# ...                                                   ...         ...     ...
# 121160  https://thumbs4.properati.com/0/zeLNBuyylOJL7z...         NaN     NaN
# 121209  https://thumbs4.properati.com/0/zeLNBuyylOJL7z...         NaN     NaN
# 121215  https://thumbs4.properati.com/1/bjms0KnaAnlNoQ...         NaN     NaN
# 121217  https://thumbs4.properati.com/9/YAe_-2gRVykADP...         NaN     NaN
# 121219  https://thumbs4.properati.com/8/mNEsnQWqB7joBF...         NaN     NaN
#
# [32316 rows x 28 columns]

# %%
data_caba.loc[:,"price_aprox_usd"]
# Out:
# 0          62000
# 2          72000
# 3          95000
# 7         138000
# 8         195000
#            ...
# 121160    410000
# 121209    410000
# 121215    870000
# 121217    131500
# 121219    129000
# Name: price_aprox_usd, Length: 32316, dtype: object

# %%
# aun quedarian 3122 propiedades sin precio
data_caba.price_aprox_usd.isnull().sum()
# Out:
# 3122
